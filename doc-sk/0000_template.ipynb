# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()">
#   <input type="submit" id="toggleButton" value="Show Code">
# </form>

# %% [markdown]
# Mena farieb:  aqua, black, blue, fuchsia, gray (or grey), green, lime, maroon, navy, olive, purple, red, silver, teal, white, and yellow
# https://htmlcolorcodes.com/color-names/
#
# # <font color='Blue'> Kapitola  </font>
#
# ## <font color='red'> Nadpis </font>
#
# ### <font color='green'> Podnadpis</font>
#
# #### <font color='brown'> Sekcia </font>
#
# ---
#
# # <font color='Blue'> <i><b>Kapitola</i></b> <font color='red'>
#
# ## <font color='red'> <i><b>Nadpis</i></b> </font>
#
# ### <font color='green'> <i><b>Podnadpis</i></b> </font>
#
# #### <font color='brown'> <i><b>Sekcia</i></b> </font>
#
#
# Pre písanie tučných a šikmých písiem v je možné použiť aj alternatívnu formu pomocou hviezdičiek
#
# # <font color='Blue'> ***Kapitola*** </font>
#
# ## <font color='red'> ***Nadpis*** </font>
#
# ### <font color='green'> ***Podnadpis*** </font>
#
# #### <font color='brown'> ***Sekcia*** </font>
#
# ---
#
# ## Medzery pre generovanie do LaTex-u
#
# Riadenie toku textu pomocou tag-ov v komentároch, neviditeľné v renderovanm texte
#
# * MEDSKIP
#
# <!-- MEDSKIP -->
#
# * SMALLSKIP
#
# <!-- SMALLSKIP -->
#
# ---

# %% [markdown]
# ## Rovnice
#
# Štandardné rovnice pomocou syntaxe LaTex-u
#
# \begin{equation*}
# x = y
# \end{equation*}
#
# Sústava rovnic pomocou *align*
#
# \begin{align*}
# x &= y \\
# z &= w
# \end{align*}
#
# ---

# %% [markdown]
# ## Farba textu, pozadie textu, bloku a výpisu programu
#
# <span style="color:red"> červený text </span>
#
# <span style='background:yellow'> žlté pozadie  </span>
#
# <span style="color:red; background:yellow;">  farebny text s pozadím </span>
#
#
# <div class="alert alert-info alert-info">
# This is a blue colored box
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>
#
# <div class="alert-success">
# This is a green colored box
# </div>
#
# <br>
# <div class="alert alert-danger" role="alert">
#   <strong>Oh snap!</strong> Change a few things up and try submitting again.
# </div>
#
#
# <div class="btn-group" role="group" aria-label="Basic example">
#   <button type="button" class="btn btn-secondary">Left</button>
#   <button type="button" class="btn btn-secondary">Middle</button>
#   <button type="button" class="btn btn-secondary">Right</button>
# </div>
#
#
# ```C
# /*
#  * Kod fragmentu programu
#  */
# void EXTI15_10_IRQHandler(void)
# {
#     // vyfarbeny kod programu podla jazyka
#     int x=123;
#     for(int i=0; i<10, i++){
#         x=x+1;
#     }
# }
# ```
#
# ## Horizontalne čiary
# ***
# ---
# ___

# %% [markdown]
# ## Import obrazku a vyvolanie externeho editora

# %%
import os
from IPython.display import Image
Image(filename='./geo/0080_keplerov_zakon.png', width=420)
#_ = os.system('geogebra ./geo/0080_keplerov_zakon.ggb &')

from IPython.display import Image
Image(filename='./img/.png', width=420)

# %% [markdown]
# <img src="./img/banner_02.png" width="800">
# <img src="./img/img_0100.png" width="400">

# %% [markdown]
# ## Fonty
#
# <span style='font-family:Georgia'> It is Georgia font.
#
# <span style='font-family:Helvetica'> It is  Helvetica font.
#
#
# <span style='font-family:"Times New Roman"'> <span styel=''>It is "Times New Roman" font.
#
# <span style='font-family:serif'> It is serif font.
#
# <span style='font-family:sans-serif'> It is sans-serif font.
#
# *Italic*  or _Italic_
#
# **Bold**
#
# ***Bold and Italic***
#
# ~~Scratch Me.~~
#
#
# > 1 Blockquotes
# >> 2 Blockquotes
# >>> 3 Blockquotes
# >>>> 4 Blockquotes
# >>>>>>>> 8 Blockquotes

# %% [markdown]
# # Navigation button
#
# Skok na ID v notebooku
#
# Označenie linky
# <a id =6> </a> <br> Start of Notebook
#
#
# Skok
# [Start of NoteBook](#6)

# %% [markdown]
# <nav class="navbar navbar-expand-lg navbar-light bg-light">
#   <a class="navbar-brand" href="#">Navbar</a>
#   <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">
#     <span class="navbar-toggler-icon"></span>
#   </button>
#
#   <div class="collapse navbar-collapse" id="navbarSupportedContent">
#     <ul class="navbar-nav mr-auto">
#       <li class="nav-item active">
#         <a class="nav-link" href="#">Home <span class="sr-only">(current)</span></a>
#       </li>
#       <li class="nav-item">
#         <a class="nav-link" href="#">Link</a>
#       </li>
#       <li class="nav-item">
#         <a class="nav-link disabled" href="#">Disabled</a>
#       </li>
#     </ul>
#     <form class="form-inline my-2 my-lg-0">
#       <input class="form-control mr-sm-2" type="text" placeholder="Search" aria-label="Search">
#       <button class="btn btn-outline-success my-2 my-sm-0" type="submit">Search</button>
#     </form>
#   </div>
# </nav>
